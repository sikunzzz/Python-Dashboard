IZakKdz4ZsA+tmJ0tnZy0j7gLPfQwGxBpEKxaqTgX51W3RmcBibsALo2PIm\\nAtLBX0eE1xooVf7yvyRV5vFH0INTv/ho2nCZ13LWtVmwj7ba8/wAUE+H4LRGMLa9\\nngiZbOGlLAg+1FObBLjQRjDMbELEeV58HhfmY/kCgYEAkxcuBL0gLq06JoLtDSC6\\n7Bfp/Fj4IV6OChAYN60SFU8VnDoopV6sA+5CiZbWzu2ob+Agh/i7PQQxSs1s1tR1\\nsauVB8DUXUqAztSfKdymKXWafpUnTmwXzsd849Z75Y0Er/HwLsgB30GDhQ+BVnKJ\\n4Ih5xzWVb6ofozTA8IdHh2E=\\n-----END PRIVATE KEY-----\\n","client_email":"s4s8bso2qk5cvv8e5ts8ajhmsq8b0e@tr-data-workbench.iam.gserviceaccount.com","client_id":"113639508953850221246","auth_uri":"https://accounts.google.com/o/oauth2/auth","token_uri":"https://oauth2.googleapis.com/token","auth_provider_x509_cert_url":"https://www.googleapis.com/oauth2/v1/certs","client_x509_cert_url":"https://www.googleapis.com/robot/v1/metadata/x509/s4s8bso2qk5cvv8e5ts8ajhmsq8b0e%40tr-data-workbench.iam.gserviceaccount.com"}') # your personal key for Tick History on BigQuery
proj = u'tr-data-workbench'
cred = service_account.Credentials.from_service_account_info(personal_cred)

# %%
# The query to send to BigQuery
query = """
    SELECT 
      RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type 
    FROM
      `tr-data-workbench.Futures.L1_Q4_2018`
    WHERE 
        Type in ("Trade", "Quote")
        AND
        Date_Time between '2018-10-01 9:00:00' and '2018-10-5 16:00:00'
        AND
        RIC="CLc1"
    ORDER BY Date_Time
    
"""
df = pandas_gbq.read_gbq(query, project_id=proj, credentials=cred, dialect='standard')

# Update the index to be a DateTimeIndex. Remove and timezone localization, which can effect plotting.
df['t'] = pd.to_datetime(df.Date_Time)
df.set_index('t', drop=True, inplace=True)
df = df.tz_localize(None)

display(df.head())
display(df.tail())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-5017e73afb4a> in <module>()
#      14
#      15 """
# ---> 16 df = pandas_gbq.read_gbq(query, project_id=proj, credentials=cred, dialect='standard')
#      17
#      18 # Update the index to be a DateTimeIndex. Remove and timezone localization, which can effect plotting.
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_gbq\gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, verbose, private_key)
#     970     )
#     971
# --> 972     final_df = connector.run_query(query, configuration=configuration)
#     973
#     974     # Reindex the DataFrame on the provided column
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_gbq\gbq.py in run_query(self, query, **kwargs)
#     535         nullsafe_dtypes = _bqschema_to_nullsafe_dtypes(schema_fields)
#     536         df = rows_iter.to_dataframe(
# --> 537             dtypes=nullsafe_dtypes, bqstorage_client=self.bqstorage_client
#     538         )
#     539
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type)
#    1643         frames = []
#    1644         for frame in self._to_dataframe_iterable(
# -> 1645             bqstorage_client=bqstorage_client, dtypes=dtypes
#    1646         ):
#    1647             frames.append(frame)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in _to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1435             )
#    1436         )
# -> 1437         for item in tabledata_list_download():
#    1438             yield item
#    1439
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in download_dataframe_tabledata_list(pages, schema, dtypes)
#     411     """Use (slower, but free) tabledata.list to construct a DataFrame."""
#     412     column_names = [field.name for field in schema]
# --> 413     for page in pages:
#     414         yield _tabledata_list_page_to_dataframe(page, column_names, dtypes)
#     415
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\api_core\page_iterator.py in _page_iter(self, increment)
#     233             Page: each page of items from the API.
#     234         """
# --> 235         page = self._next_page()
#     236         while page is not None:
#     237             self.page_number += 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\api_core\page_iterator.py in _next_page(self)
#     359         """
#     360         if self._has_next_page():
# --> 361             response = self._get_next_page_response()
#     362             items = response.get(self._items_key, ())
#     363             page = Page(self, items, self.item_to_value)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in _get_next_page_response(self)
#    1367             params["maxResults"] = self._page_size
#    1368         return self.api_request(
# -> 1369             method=self._HTTP_METHOD, path=self.path, query_params=params
#    1370         )
#    1371
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\bigquery\client.py in _call_api(self, retry, **kwargs)
#     474         if retry:
#     475             call = retry(call)
# --> 476         return call()
#     477
#     478     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\api_core\retry.py in retry_wrapped_func(*args, **kwargs)
#     271                 sleep_generator,
#     272                 self._deadline,
# --> 273                 on_error=on_error,
#     274             )
#     275
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\api_core\retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     180     for sleep in sleep_generator:
#     181         try:
# --> 182             return target()
#     183
#     184         # pylint: disable=broad-except
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\google\cloud\_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     394
#     395         if expect_json and response.content:
# --> 396             return response.json()
#     397         else:
#     398             return response.content
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simplejson\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     516             parse_constant is None and object_pairs_hook is None
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#     520         cls = JSONDecoder
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simplejson\decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\simplejson\decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     398             elif ord0 == 0xef and s[idx:idx + 3] == '\xef\xbb\xbf':
#     399                 idx += 3
# --> 400         return self.scan_once(s, idx=_w(s, idx).end())
#
# MemoryError:

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f64e6132b90c> in <module>()
# ----> 1 del final_df
#
# NameError: name 'final_df' is not defined

# %%
from pandas.tseries.offsets import BDay

# %%
date_range=pd.date_range(start="2018-10-01", end="2018-12-31", freq=BDay())

# %%
int( np.ceil(len(date_range)/5))
print(len(date_range))
# Out:
# 66

# %%
part_query1 = """SELECT 
      RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type 
    FROM
      `tr-data-workbench.Futures.L1_Q4_2018`
    WHERE 
        Type in ("Trade", "Quote")
        AND
        Date_Time between
"""

ric_list = ["NGc1", "CLc1"]
for ric in ric_list:
    part_query2 = " AND RIC=" + "'" + ric + "'" + " ORDER BY Date_Time"
    
    for i in range(int( np.ceil(len(date_range)/5))):
        file_name = os.getcwd() + "/TickData" + ric + "_"+ str(date_range[(0+i*5)]) + "_" + str(date_range[(5+i*5)]) + ".json"
        if os.path.exists(file_name):
            next
        else:
            query =  part_query1 + "'" + str(date_range[(0+i*5)]) + " 8:00:00" + "'" + "and" + "'" + str(date_range[(5+i*5)]) + " 16:00:00" + "'" + part_query2    
            df = pandas_gbq.read_gbq(query, project_id=proj, credentials=cred, dialect='standard')
            display(df)
            with open(file_name, "+w") as f:
                f.write(df.to_json())
            del df
# Out:
#   File "<ipython-input-1-f78802391d47>", line 23
#     with open(, "+w") as f:
#               ^
# SyntaxError: invalid syntax

# %%
from bokeh.plotting import figure
from bokeh.io import output_file, show

p = figure(title="WTI Oil Price at National Day 2018",
            x_axis_label='Date',
            y_axis_label='Price')
p.line(df.index, df.Bid_Price, legend="Price", line_width=2)
output_file("lines.html")
show(p)

# %%
query_list
# Out:
# 'SELECT \n      RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type \n    FROM\n      `tr-data-workbench.Futures.L1_Q4_2018`\n    WHERE \n        Type in ("Trade", "Quote")\n        AND\n        Date_Time between\n\'2018-10-18 00:00:00 8:00:00\'and\'2018-10-25 00:00:00 16:00:00\' AND\n        RIC="CLc1"\n    ORDER BY Date_Time\n'

# %%
jString = df.reset_index().to_json()

# %%
with open('trial.json', "+w") as f:
    f.write(jString)

df = pd.read_json('trial.json')

# %%
df.set_index("t").sort_index()
# Out:
#                 RIC               Date_Time  Bid_Price  Bid_Size  Ask_Price  \
# t
# 1538384400287  CLc1 2018-10-01 09:00:00.287      73.33      18.0      73.34
# 1538384402699  CLc1 2018-10-01 09:00:02.699      73.33      16.0      73.34
# 1538384402699  CLc1 2018-10-01 09:00:02.699      73.33      16.0      73.34
# 1538384407255  CLc1 2018-10-01 09:00:07.255      73.33      17.0      73.34
# 1538384407543  CLc1 2018-10-01 09:00:07.543      73.33      21.0      73.34
# 1538384407543  CLc1 2018-10-01 09:00:07.543      73.33      20.0      73.34
# 1538384407543  CLc1 2018-10-01 09:00:07.543      73.33      19.0      73.34
# 1538384407543  CLc1 2018-10-01 09:00:07.543      73.33      21.0      73.34
# 1538384407543  CLc1 2018-10-01 09:00:07.543      73.33      22.0      73.34
# 1538384407563  CLc1 2018-10-01 09:00:07.563      73.33      21.0      73.34
# 1538384407563  CLc1 2018-10-01 09:00:07.563      73.33      23.0      73.34
# 1538384409383  CLc1 2018-10-01 09:00:09.383        NaN       NaN        NaN
# 1538384409383  CLc1 2018-10-01 09:00:09.383      73.33      21.0      73.34
# 1538384409383  CLc1 2018-10-01 09:00:09.383      73.33      23.0      73.34
# 1538409599794       9.0    NaN     NaN  Quote
# 1538409599794       8.0    NaN     NaN  Quote
# 1538409599794       9.0    NaN     NaN  Quote
# 1538409599794       9.0    NaN     NaN  Quote
# 1538409599806       9.0    NaN     NaN  Quote
# 1538409599806       8.0    NaN     NaN  Quote
# 1538409599946       9.0    NaN     NaN  Quote
# 1538409599946      10.0    NaN     NaN  Quote
# 1538409599946      17.0    NaN     NaN  Quote
# 1538409599946      16.0    NaN     NaN  Quote
# 1538409599946      12.0    NaN     NaN  Quote
# 1538409599946      11.0    NaN     NaN  Quote
# 1538409599946      16.0    NaN     NaN  Quote
# 1538409599946      18.0    NaN     NaN  Quote
# 1538409599946      18.0    NaN     NaN  Quote
#
# [1269542 rows x 9 columns]

# %%
open("c:/Users/canze/Bokeh-Dashboard/retrieve_data_gas.sql").read()
# Out:
# 'SELECT\n      RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type\n    FROM\n      `tr-data-workbench.Futures.L1_Q4_2018`\n    WHERE\n        Type in ("Trade", "Quote")\n        AND\n        Date_Time between \'2018-10-01 9:00:00\' and \'2018-10-1 16:00:00\'\n        AND\n        RIC="NGc1"\n    ORDER BY Date_Time'

# %%
""" SELECT
    RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type
    FROM
    `tr-data-workbench.Futures.L1_Q4_2018`
    WHERE
    Type in ("Trade", "Quote")
    AND
    Date_Time between '2018-10-01 9:00:00' and '2018-10-1 16:00:00'
    AND
    RIC=""" +  " 'NGc1' " +" ORDER BY Date_Time"
# Out:
# ' SELECT\n    RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type\n    FROM\n    `tr-data-workbench.Futures.L1_Q4_2018`\n    WHERE\n    Type in ("Trade", "Quote")\n    AND\n    Date_Time between \'2018-10-01 9:00:00\' and \'2018-10-1 16:00:00\'\n    AND\n    RIC= \'NGc1\'  ORDER BY Date_Time'

# %%
query
# Out:
# '\n    SELECT \n      RIC, Date_Time, Bid_Price, Bid_Size, Ask_Price, Ask_Size, Price, Volume, Type \n    FROM\n      `tr-data-workbench.Futures.L1_Q4_2018`\n    WHERE \n        Type in ("Trade", "Quote")\n        AND\n        Date_Time between \'2018-10-01 9:00:00\' and \'2018-10-1 16:00:00\'\n        AND\n        RIC="CLc1"\n    ORDER BY Date_Time\n    \n'

# %%
a = "NGc1"

# %%
"'" + a +"'"
# Out:
# "'NGc1'"

# %%
jString = df.reset_index().to_json()

# %%
jString

# %%
import pandas as pd
import os

# %%
final_df = pd.read_json( os.getcwd() + "/TRHist.json" )

# %%
final_df.
# Out:
#              CLc1   NGc1
# 2016-11-01  46.32  2.844
# 2016-11-02  45.48  2.768
# 2016-11-03  44.63  2.810
# 2016-11-04  44.10  2.757
# 2016-11-07  44.91  2.826
# 2016-11-08  44.80  2.607
# 2016-11-09  45.29  2.682
# 2016-11-10  44.24  2.647
# 2016-11-11  43.10  2.600
# 2016-11-14  43.65  2.746
# 2016-11-15  45.73  2.700
# 2016-11-16  45.31  2.751
# 2016-11-17  44.86  2.680
# 2016-11-18  45.31  2.838
# 2016-11-21    NaN  2.960
# 2016-11-22  47.83  2.925
# 2016-11-23  47.91  2.995
# 2016-11-25  45.91  3.066
# 2016-11-28  46.84    NaN
# 2016-11-29  45.20  3.315
# 2016-11-30  48.94  3.339
# 2016-12-01  50.83  3.528
# 2016-12-02  51.64  3.451
# 2016-12-05  50.92  3.586
# 2016-12-06  50.88  3.628
# 2016-12-07  49.80  3.556
# 2016-12-08  50.88  3.707
# 2016-12-09  51.45  3.708
# 2016-12-12  52.35  3.505
# 2016-12-13  52.42  3.470
# ...           ...    ...
# 2018-09-20    NaN  2.948
# 2018-09-21  70.70  2.979
# 2018-09-24  72.20  3.040
# 2018-09-25  72.04  3.065
# 2018-09-26  71.99    NaN
# 2018-09-27  72.17  3.058
# 2018-09-28  73.50  3.000
# 2018-10-01  75.44  3.109
# 2018-10-02  75.01  3.157
# 2018-10-03  76.17  3.235
# 2018-10-04  74.62  3.184
# 2018-10-05  74.25  3.139
# 2018-10-08  74.17  3.277
# 2018-10-09  74.64  3.302
# 2018-10-10  72.58  3.267
# 2018-10-11  70.90  3.226
# 2018-10-12  71.45  3.143
# 2018-10-15  71.67  3.252
# 2018-10-16  72.12  3.249
# 2018-10-17  70.02  3.315
# 2018-10-18  68.45  3.216
# 2018-10-19  68.56  3.219
# 2018-10-22    NaN  3.125
# 2018-10-23  66.05  3.213
# 2018-10-24  66.31  3.171
# 2018-10-25  66.95  3.164
# 2018-10-26  67.57  3.186
# 2018-10-29  66.65    NaN
# 2018-10-30  66.32  3.190
# 2018-10-31  64.83  3.270
#
# [504 rows x 2 columns]

# %%
from datetime import datetime as dt

# %%
sd = dt(2017,10,31)
ed = dt(2018,3,31)

# %%
sub_df = final_df.loc[sd:ed]["NGc1"]

# %%
sub_df.median()
# Out:
# 2.7904999999999998

# %%
dff = pd.DataFrame( {"Mean": sub_df.resample("1M").mean()})

# %%
dff
# Out:
#                 Mean
# 2017-10-31  2.902000
# 2017-11-30  3.053200
# 2017-12-31  2.771211
# 2018-01-31  3.133100
# 2018-02-28  2.664833
# 2018-03-31  2.697050

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-64-3aed5f69835b> in <module>()
# ----> 1 df.reset_index(inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4134                 # to ndarray and maybe infer different dtype
#    4135                 level_values = _maybe_casted_values(lev, lab)
# -> 4136                 new_obj.insert(0, name, level_values)
#    4137
#    4138         new_obj.index = new_index
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3215         """
#    3216         self._ensure_valid_index(value)
# -> 3217         value = self._sanitize_column(column, value, broadcast=False)
#    3218         self._data.insert(loc, column, value,
#    3219                           allow_duplicates=allow_duplicates)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3397                 value = value.copy(deep=True)
#    3398             else:
# -> 3399                 value = value.copy()
#    3400
#    3401             # possibly infer to datetimelike
#
# MemoryError:
